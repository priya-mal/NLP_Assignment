# %% [markdown]
# ### NLP Assignment

# %% [markdown]
# **Problem:** Find the frequency of words in a webpage. User can use urllib and BeautifulSoup to extract text from
# webpage.

# %%
from bs4 import BeautifulSoup 
import urllib.request 
import nltk 
from nltk.corpus import stopwords 

response = urllib.request.urlopen('http://php.net/') 

html = response.read() 

text = BeautifulSoup(html,"html5lib").get_text(strip=True)

tokens = [t for t in text.split()] 

clean_tokens = tokens[:] 

words = stopwords.words('english') 
for token in tokens: 
    if token in words: 
        clean_tokens.remove(token) 

freq = nltk.FreqDist(clean_tokens) 
for key,val in freq.items(): 
    print (str(key) + ':' + str(val))
# Out:
# PHP::1
# Hypertext:1
# PreprocessorDownloadsDocumentationGet:1
# InvolvedHelpGetting:1
# StartedIntroductionA:1
# simple:1
# tutorialLanguage:1
# ReferenceBasic:1
# syntaxTypesVariablesConstantsExpressionsOperatorsControl:1
# StructuresFunctionsClasses:1
# ObjectsNamespacesErrorsExceptionsGeneratorsReferences:1
# ExplainedPredefined:1
# VariablesPredefined:1
# ExceptionsPredefined:1
# Interfaces:1
# ClassesContext:1
# options:1
# parametersSupported:1
# Protocols:1
# WrappersSecurityIntroductionGeneral:1
# considerationsInstalled:1
# CGI:1
# binaryInstalled:1
# Apache:1
# moduleSession:1
# SecurityFilesystem:1
# SecurityDatabase:1
# SecurityError:1
# ReportingUsing:1
# Register:1
# GlobalsUser:1
# Submitted:1
# DataMagic:1
# QuotesHiding:1
# PHPKeeping:1
# CurrentFeaturesHTTP:1
# authentication:1
# PHPCookiesSessionsDealing:1
# XFormsHandling:1
# file:1
# uploadsUsing:1
# remote:1
# filesConnection:1
# handlingPersistent:1
# Database:1
# ConnectionsSafe:1
# ModeCommand:1
# line:1
# usageGarbage:1
# CollectionDTrace:1
# Dynamic:1
# TracingFunction:1
# ReferenceAffecting:1
# PHP's:1
# BehaviourAudio:1
# Formats:1
# ManipulationAuthentication:1
# ServicesCommand:1
# Line:1
# Specific:2
# ExtensionsCompression:1
# Archive:1
# ExtensionsCredit:1
# Card:1
# ProcessingCryptography:1
# ExtensionsDatabase:1
# ExtensionsDate:1
# Time:1
# Related:4
# ExtensionsFile:1
# System:1
# ExtensionsHuman:1
# Language:1
# Character:1
# Encoding:1
# SupportImage:1
# Processing:1
# GenerationMail:1
# ExtensionsMathematical:1
# ExtensionsNon-Text:1
# MIME:1
# OutputProcess:1
# Control:1
# ExtensionsOther:2
# Basic:1
# ServicesSearch:1
# Engine:1
# ExtensionsServer:1
# ExtensionsSession:1
# ExtensionsText:1
# ProcessingVariable:1
# Type:1
# ExtensionsWeb:1
# ServicesWindows:1
# Only:1
# ExtensionsXML:1
# ManipulationGUI:1
# ExtensionsKeyboard:1
# Shortcuts?This:1
# helpjNext:1
# menu:2
# itemkPrevious:1
# itemg:1
# pPrevious:1
# man:2
# pageg:1
# nNext:1
# pageGScroll:1
# bottomg:1
# gScroll:1
# topg:1
# hGoto:1
# homepageg:1
# sGoto:1
# search(current:1
# page)/Focus:1
# search:1
# boxPHP:1
# popular:2
# general-purpose:1
# scripting:1
# language:1
# especially:1
# suited:1
# web:1
# development.Fast,:1
# flexible:1
# pragmatic,:1
# PHP:203
# powers:1
# everything:1
# blog:1
# websites:1
# world.Download7.4.5·Release:1
# Notes·Upgrading7.3.17·Release:1
# Notes·Upgrading7.2.30·Release:1
# Notes·Upgrading17:1
# Apr:3
# 2020PHP:7
# 7.2.30:2
# Release:15
# AnnouncementThe:1
# development:12
# team:37
# announces:12
# immediate:12
# availability:12
# 7.2.30.:1
# This:25
# security:5
# release.All:3
# 7.2:3
# users:12
# encouraged:12
# upgrade:7
# version.For:20
# source:43
# downloads:37
# please:37
# visit:37
# ourdownloads:6
# page,:6
# Windows:24
# binaries:24
# found:104
# onwindows.php.net/download/.:6
# The:20
# list:42
# changes:15
# recorded:7
# theChangeLog.16:2
# 7.4.5:2
# ReleasedThe:22
# 7.4.5.:1
# release:133
# also:38
# contains:4
# several:4
# bug:5
# fixes.All:3
# 7.4:14
# 7.3.17:3
# 7.3:15
# theChangeLog.19:3
# Mar:3
# 7.4.4:2
# Released!The:6
# 7.4.4.:1
# fix:1
# ourdownloadspage:1
# thePHP:26
# Windowssite.:1
# 7.2.29:2
# 7.2.29.:1
# 7.3.16:2
# 7.3.16.:1
# theChangeLog.14:1
# Nov:3
# 2019PHP:12
# 7.4.0RC6:2
# glad:25
# announce:25
# sixth:2
# candidate:6
# 7.4::9
# 7.4.0RC6.:1
# continues:11
# cycle,:13
# rough:25
# outline:25
# specified:25
# Wiki.Please:6
# DO:30
# NOT:30
# use:13
# version:43
# production,:13
# early:13
# test:43
# thedownload:25
# page.Please:13
# carefully:25
# report:30
# issues:25
# thebug:30
# reporting:25
# system.For:6
# information:30
# new:30
# features:30
# changes,:30
# read:35
# theNEWSfile,:30
# theUPGRADINGfile:30
# complete:30
# upgrading:30
# notes.:30
# These:30
# files:30
# archive.The:25
# next:32
# would:25
# be7.4.0,:1
# planned:30
# November:4
# 28th.The:1
# signatures:25
# inthe:25
# manifestor:25
# onthe:25
# QA:25
# site.Thank:25
# helping:30
# us:30
# make:30
# better.31:2
# Oct:6
# 7.4.0RC5:2
# released!The:4
# fifth:2
# 7.4.0RC5.:1
# be7.4.0RC6,:1
# 14th.The:1
# better.18:1
# 7.4.0RC4:2
# fourth:3
# 7.4.0RC4.:1
# be7.4.0RC5,:1
# October:5
# 31st.The:1
# better.03:1
# 7.4.0RC3:2
# third:6
# 7.4.0RC3.:1
# be7.4.0RC4,:1
# 17th.The:1
# better.19:2
# Sep:5
# 7.4.0RC2:2
# second:5
# 7.4.0RC2.:1
# be7.4.0RC3,:1
# 3rd.The:1
# better.05:2
# 7.4.0RC1:2
# first:7
# 7.4.0RC1.:1
# be7.4.0RC2,:1
# September:4
# 19th.The:2
# better.22:2
# Aug:7
# 7.4.0beta4:2
# last:2
# beta:5
# 7.4.0beta4.:1
# Wiki.For:19
# system.Please:7
# beRC:1
# 1,:4
# 5th.The:1
# better.08:2
# 7.4.0beta2:2
# 7.4.0beta2.:1
# beBeta:3
# 3,:4
# August:5
# 22nd.The:2
# better.25:2
# Jul:5
# 7.4.0beta1:2
# 7.4.0beta1.:1
# 2,:4
# 8th.The:2
# better.11:2
# 7.4.0:12
# alpha:6
# 3:10
# ReleasedPHP:4
# version,:10
# Alpha:20
# 3.:4
# July:4
# 25th.The:2
# better.26:1
# Jun:4
# 2:4
# 2.:3
# 11th.The:2
# better.13:2
# 1:6
# 1.:3
# starts:2
# June:2
# 27.The:1
# 2018PHP:14
# 7.3.0RC6:2
# presumably:1
# 7.3.0:23
# pre-release,:6
# 7.3.0RC6.:1
# cycle:12
# page.:12
# sources:17
# onwindows.php.net/qa/.Please:12
# system.THIS:17
# IS:17
# A:17
# DEVELOPMENT:17
# PREVIEW:17
# -:17
# USE:17
# IT:17
# IN:17
# PRODUCTION!For:17
# Internal:8
# listed:8
# theUPGRADING.INTERNALSfile.:8
# (GA),:1
# December:1
# 6th.The:1
# 7.3.0RC5:2
# 7.3.0RC5.:1
# RC6,:1
# 7.3.0RC4:2
# 7.3.0RC4.:1
# RC5,:1
# 7.3.0RC3:2
# 7.3.0RC3.:1
# RC4,:1
# better.28:2
# 7.3.0RC2:2
# 7.3.0RC2.:1
# RC3,:1
# 7.3.0RC1:2
# 7.3.0RC1.:1
# RC2,:1
# 27th.The:1
# better.30:1
# 7.3.0.beta3:1
# seventh:1
# 7.3.0beta3.:1
# 7.3.0beta3:1
# RC1,:1
# 13th.The:1
# better.16:1
# 7.3.0.beta2:1
# 7.3.0beta2.:1
# 7.3.0beta2:1
# Beta:7
# 30th.The:1
# better.02:1
# 7.3.0.beta1:1
# 7.3.0beta1.:1
# 7.3.0beta1:1
# 16th.The:1
# 7.3.0alpha4:2
# 7.3.0alpha4.:1
# 2nd.The:1
# better.21:1
# 5.The:1
# better.07:1
# 21.The:1
# better.01:1
# Feb:1
# 7.2.2:2
# 7.2.2.:1
# bugfix:1
# release,:1
# fixes:2
# included.All:1
# theChangeLog.12:1
# 2017PHP:5
# 7.2.0:15
# Candidate:14
# 4:2
# RC4.:1
# 7.2.0.:4
# All:5
# carefully,:5
# bugs:5
# incompatibilities:5
# tracking:5
# archive.For:5
# thedownloadpage,:5
# atwindows.php.net/qa/.The:4
# announced:2
# 26th:1
# October.:2
# You:5
# full:5
# releases:5
# onour:4
# wiki.Thank:4
# RC3.:1
# 12th:1
# released:3
# 14th:1
# September.:1
# better.17:1
# final:1
# 31th:1
# August.:1
# better.06:1
# improvements:1
# relative:1
# onwindows.php.net/qa/.The:1
# 20th:1
# July.:1
# ourwiki.Thank:1
# better.Older:1
# News:1
# EntriesUpcoming:1
# conferencesThe:1
# Online:2
# ConferenceDutch:1
# Conference:1
# 2020:1
# –:1
# Editionphp[tek]:1
# Russia:1
# 2020User:1
# Group:1
# EventsSpecial:1
# ThanksSocial:1
# media@official_phpCopyright:1
# ©:1
# 2001-2020:1
# GroupMy:1
# PHP.netContactOther:1
# PHP.net:1
# sitesPrivacy:1
# policy:1
